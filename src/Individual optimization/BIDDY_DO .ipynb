# %%
import numpy as np
import matplotlib.pyplot as plt

import random

import io 
import pandas as pd  
import pyreadr

from load_data import *
from pred_score import *
from Filter_FS import *
from hybrid_FS import *
from overlap_genes import *

# %% [markdown]
# # Baseline with preselected genes for BIDDY DO

# %%
#Load preprocess data
DO = np.array(pd.read_csv ('../data/processed_data/DOcsv_process.csv'))
y = np.array(DO[:,-1],dtype=int)
DO = DO[:,0:-1]

# %%
#Predict and evaluate
model = FamiliesClusters(np.unique(y),compute_precision,True)
pred = model.fit_predict(DO,y)

# %%
print(DO.shape, len(pred))
acc = model.score_
print(acc)
# Out:
# (112, 4021) 112
# 0.98

# %%
print("sensitivity, specificity, precision, NPV, FDR, FNR = ", compute_statTP(y,pred))
# Out:
# sensitivity, specificity, precision, NPV, FDR, FNR =  (0.875, 0.9997304582210242, 0.98, 0.9981162540365985, 0.02, 0.125)

# %%
#Fixing seed to get reproducible results
random.seed(3)
np.random.seed(3)

# %% [markdown]
# # Filter methods

# %% [markdown]
# # Mutual information maximizer (MIM)

# %%
N = np.arange(30,41,1)
#N = np.array([40,50,60,70,80])
best_subset, best_score = MIR(y, DO, FamiliesClusters, compute_precision,True,N, 3, plot=True)
print(best_subset, best_score)
# Out:
# [  34   93  145  230  364  385  638  639  717  921 1130 1226 1247 1272
#  1445 1576 1749 1892 2027 2042 2222 2490 2607 2707 2712 2843 3214 3633
#  3811 3840 4004] 1.0

# %%
print(len(best_subset))
#Predict and evaluate
model = FamiliesClusters(np.unique(y),compute_precision,True)
pred = model.fit_predict(DO[:, best_subset],y)

print("sensitivity, specificity, precision, NPV, FDR, FNR = ", compute_statTP(y,pred))
# Out:
# 31
# sensitivity, specificity, precision, NPV, FDR, FNR =  (0.9642857142857143, 1.0, 1.0, 0.9993939393939394, 0.0, 0.03571428571428571)

# %% [markdown]
# # Mutual information feature selection (MIFS)

# %%
#N = np.array([50,80,100,125,150,200,250,300,350])
N = np.array([200,220,240,260,280,300,320,340,360])
best_subset, best_score = MIFS(y, DO, FamiliesClusters, compute_precision,True,N, 0.1, plot=True)
print(best_subset, best_score)
# Out:
# [  19   36   62   66   68   69   91   92   99  118  130  155  156  165
#   168  172  174  192  218  225  241  242  265  267  268  292  295  309
#   328  348  353  369  381  405  410  427  439  440  449  452  457  463
#   483  491  498  503  537  557  566  581  589  595  603  604  609  616
#   640  641  642  646  651  670  672  673  692  695  721  738  745  750
#   755  758  768  774  779  786  799  841  854  860  865  870  895  900
#   906  913  917  918  924  925  932  971  985  994 1027 1039 1049 1065
#  1074 1077 1106 1128 1131 1133 1136 1137 1163 1165 1171 1178 1180 1193
#  1211 1213 1231 1264 1273 1285 1309 1312 1347 1355 1360 1398 1437 1443
#  1470 1487 1527 1548 1564 1602 1607 1617 1619 1631 1638 1653 1669 1684
#  1686 1687 1707 1717 1727 1733 1747 1753 1778 1781 1784 1813 1818 1819
#  1823 1841 1847 1854 1866 1879 1921 1922 1937 1942 1945 1949 1951 1955
#  1959 1963 1983 1991 1999 2010 2038 2057 2060 2069 2070 2072 2090 2091
#  2092 2093 2096 2103 2108 2110 2115 2121 2137 2141 2152 2165 2173 2197
#  2202 2211 2216 2220 2223 2231 2245 2248 2255 2264 2292 2328 2333 2336
#  2362 2373 2378 2380 2394 2410 2441 2451 2460 2463 2467 2468 2472 2473
#  2487 2495 2511 2518 2527 2532 2545 2551 2556 2560 2564 2587 2595 2597
#  2606 2611 2619 2622 2645 2649 2652 2660 2662 2668 2688 2716 2724 2747
#  2787 2790 2814 2816 2826 2827 2838 2854 2870 2873 2876 2878 2888 2894
#  2908 2944 2965 2987 3012 3024 3026 3034 3041 3072 3083 3098 3115 3154
#  3155 3163 3173 3191 3196 3198 3202 3212 3214 3218 3256 3263 3294 3305
#  3308 3320 3339 3343 3347 3352 3359 3375 3384 3388 3391 3397 3400 3401
#  3404 3419 3435 3457 3462 3479 3486 3488 3505 3515 3524 3529 3546 3568
#  3580 3590 3594 3599 3611 3612 3614 3623 3657 3697 3698 3703 3706 3713
#  3714 3717 3742 3755 3757 3760 3782 3784 3802 3847 3887 3888 3903 3925
#  3937 3939 3977 3988 3989 3991 3996 4000 4002 4009] 0.6739130434782609

# %%
print(len(best_subset))
#Predict and evaluate
model = FamiliesClusters(np.unique(y),compute_precision,True)
pred = model.fit_predict(DO[:, best_subset],y)

print("sensitivity, specificity, precision, NPV, FDR, FNR = ", compute_statTP(y,pred))
# Out:
# 360
# sensitivity, specificity, precision, NPV, FDR, FNR =  (0.5636363636363636, 0.9963334148130042, 0.6739130434782609, 0.9941463414634146, 0.32608695652173914, 0.43636363636363634)

# %% [markdown]
# # Joint Mutual Information (JMI)

# %%
N = np.arange(740,760,1)
best_subset, best_score = JMI(y, DO, FamiliesClusters, compute_precision ,True, N, plot=True)
print(best_subset, best_score)
# Out:
# [   1    3    4    5    6    7    8    9   10   16   20   23   38   39
#    40   41   44   48   50   51   53   55   59   63   65   79   81   85
#    89  113  116  119  121  123  125  131  135  145  148  160  162  170
#   171  175  180  190  202  209  210  211  214  226  230  232  233  239
#   243  244  252  260  269  274  286  287  290  298  301  302  303  305
#   334  338  344  345  350  365  373  376  383  393  401  417  419  420
#   425  432  441  454  459  460  462  469  477  488  492  494  499  500
#   501  504  507  512  514  516  519  522  526  530  538  544  548  549
#   551  552  556  563  572  575  585  587  591  592  597  598  611  612
#   626  630  636  653  659  660  661  667  674  691  704  706  708  711
#   722  724  725  736  746  749  752  757  759  765  766  773  780  785
#   789  791  792  794  802  805  820  828  830  832  838  840  842  844
#   847  848  853  866  885  890  892  894  908  926  938  942  943  947
#   954  972  974  975  976  979  983  995  997 1003 1036 1037 1041 1045
#  1046 1048 1053 1057 1062 1066 1072 1083 1085 1089 1122 1140 1150 1159
#  1160 1162 1168 1173 1177 1184 1192 1208 1212 1214 1218 1219 1233 1243
#  1244 1245 1251 1269 1272 1277 1278 1280 1303 1305 1308 1313 1321 1329
#  1335 1336 1338 1340 1341 1346 1348 1369 1370 1376 1384 1394 1396 1397
#  1401 1407 1413 1419 1420 1425 1427 1440 1454 1464 1481 1488 1490 1496
#  1498 1499 1502 1508 1515 1524 1528 1529 1530 1532 1536 1537 1543 1544
#  1546 1547 1551 1559 1560 1563 1569 1570 1571 1584 1587 1593 1599 1601
#  1603 1608 1611 1613 1614 1615 1616 1618 1624 1625 1626 1634 1643 1650
#  1656 1660 1664 1666 1667 1668 1672 1677 1688 1694 1696 1701 1702 1703
#  1713 1714 1719 1721 1722 1723 1726 1729 1734 1746 1748 1750 1764 1765
#  1783 1786 1791 1794 1800 1803 1804 1824 1827 1828 1829 1842 1851 1853
#  1858 1863 1864 1870 1878 1884 1888 1897 1900 1911 1914 1920 1931 1932
#  1933 1938 1950 1953 1956 1961 1966 1976 1982 1985 1990 1994 2000 2009
#  2019 2035 2042 2046 2049 2051 2054 2061 2063 2067 2071 2074 2075 2080
#  2095 2128 2145 2148 2155 2160 2177 2179 2186 2187 2190 2199 2215 2230
#  2246 2254 2258 2263 2265 2269 2274 2279 2280 2282 2283 2284 2289 2306
#  2319 2323 2334 2344 2346 2348 2352 2355 2363 2364 2365 2371 2384 2385
#  2392 2406 2408 2434 2437 2440 2443 2444 2446 2448 2449 2450 2455 2466
#  2470 2474 2480 2486 2490 2491 2492 2500 2502 2503 2515 2517 2521 2528
#  2530 2534 2539 2541 2544 2547 2548 2553 2554 2558 2572 2574 2575 2577
#  2579 2584 2586 2589 2591 2596 2598 2600 2601 2605 2607 2608 2618 2623
#  2626 2628 2640 2644 2647 2654 2657 2659 2676 2678 2685 2686 2694 2695
#  2696 2705 2710 2714 2715 2718 2727 2729 2732 2738 2743 2746 2748 2753
#  2755 2757 2759 2761 2763 2764 2770 2771 2772 2773 2783 2786 2789 2791
#  2795 2798 2803 2805 2817 2818 2822 2825 2830 2843 2849 2855 2858 2859
#  2861 2882 2884 2890 2897 2900 2901 2915 2931 2945 2948 2961 2964 2974
#  2999 3005 3014 3016 3020 3023 3025 3030 3033 3038 3039 3055 3056 3064
#  3068 3074 3083 3085 3089 3090 3101 3105 3107 3114 3116 3119 3129 3139
#  3148 3151 3152 3157 3187 3198 3204 3208 3213 3220 3222 3227 3228 3231
#  3232 3234 3239 3241 3243 3244 3265 3269 3272 3284 3289 3290 3303 3306
#  3313 3314 3322 3331 3342 3348 3351 3356 3376 3377 3379 3380 3381 3382
#  3389 3392 3393 3395 3403 3406 3409 3417 3421 3427 3429 3448 3451 3455
#  3464 3471 3484 3506 3508 3511 3514 3525 3539 3540 3548 3550 3555 3557
#  3558 3561 3565 3567 3568 3569 3571 3583 3584 3590 3591 3606 3621 3624
#  3625 3634 3649 3653 3656 3663 3669 3673 3682 3685 3695 3701 3711 3712
#  3718 3719 3723 3727 3735 3751 3762 3772 3777 3790 3793 3804 3808 3813
#  3821 3825 3830 3836 3838 3851 3852 3855 3856 3857 3858 3871 3874 3882
#  3883 3885 3891 3896 3901 3904 3914 3917 3925 3927 3928 3944 3946 3947
#  3955 3963 3968 3970 3971 3978 3980 3989 3991 3996 4007 4009 4011] 0.9387755102040817

# %%
print(len(best_subset))
#Predict and evaluate
model = FamiliesClusters(np.unique(y),compute_precision,True)
pred = model.fit_predict(DO[:, best_subset],y)

print("sensitivity, specificity, precision, NPV, FDR, FNR = ", compute_statTP(y,pred))
# Out:
# 741
# sensitivity, specificity, precision, NPV, FDR, FNR =  (0.8214285714285714, 0.9992121848739496, 0.9387755102040817, 0.9973787680209698, 0.061224489795918366, 0.17857142857142858)

# %% [markdown]
# # Double input symmetrical relevance (DISR)

# %%
N = np.array([80,100,125,150,200,250,300,400])
best_subset, best_score = DISR(y, DO, FamiliesClusters, compute_precision,True, N, plot=True)
print(best_subset, best_score)
# Out:
# [   4  289  303  575  585  591  592  598  612  636  653  659  660  661
#   667  704  706  708  711  724  725  749  757  759  765  773  785  791
#   794  805  820  828  838  840  842  853  866  890  926  943  975  979
#   983  995  997 1036 1041 1045 1046 1048 1066 1072 1089 1122 1140 1150
#  1162 1173 1177 1184 1192 1208 1212 1218 1219 1233 1243 1244 1269 1272
#  1278 1294 1308 1313 1329 1335 1336 1338 1340 1346 1370 1376 1384 1394
#  1396 1397 1407 1413 1419 1420 1454 1464 1481 1488 1490 1496 1498 1502
#  1508 1515 1524 1529 1530 1532 1536 1544 1551 1559 1563 1570 1571 1587
#  1593 1597 1603 1608 1611 1614 1616 1618 1624 1625 1626 1634 1643 1650
#  1656 1667 1668 1672 1677 1682 1688 1696 1701 1703 1713 1714 1719 1721
#  1723 1729 1734 1746 1783 1791 1800 1828 1829 1851 1863 1864 1870 1878
#  1900 1911 1914 1920 1931 1932 1933 1938 1950 1953 1956 1966 1982 1990
#  1994 2000 2008 2009 2019 2035 2042 2051 2054 2061 2063 2067 2074 2075
#  2080 2145 2148 2155 2160 2177 2186 2199 2215 2254 2263 2269 2279 2282
#  2283 2284 2289 2306 2319 2323 2334 2344 2346 2355 2363 2364 2384 2385
#  2406 2434 2437 2440 2443 2444 2446 2448 2449 2455 2470 2480 2482 2490
#  2491 2492 2500 2517 2528 2530 2536 2539 2544 2547 2548 2553 2577 2579
#  2589 2591 2596 2600 2601 2605 2607 2618 2623 2626 2647 2659 2676 2678
#  2685 2694 2695 2718 2732 2743 2746 2753 2755 2757 2759 2761 2763 2764
#  2770 2771 2773 2789 2791 2798 2805 2817 2818 2822 2849 2858 2859 2861
#  2882 2884 2901 2931 2948 2964 2974 2999 3016 3020 3025 3030 3033 3055
#  3056 3064 3068 3074 3083 3089 3090 3101 3129 3139 3148 3151 3152 3157
#  3187 3198 3208 3220 3222 3227 3232 3234 3243 3244 3265 3269 3272 3284
#  3290 3303 3313 3314 3342 3348 3351 3357 3377 3379 3380 3381 3382 3392
#  3393 3417 3427 3429 3471 3484 3506 3508 3511 3514 3540 3550 3561 3565
#  3567 3568 3571 3583 3584 3590 3591 3606 3621 3624 3625 3656 3663 3685
#  3711 3719 3727 3735 3751 3762 3772 3790 3793 3804 3813 3821 3825 3830
#  3856 3871 3891 3901 3904 3914 3925 3927 3928 3944 3946 3947 3955 3963
#  3968 3970 3971 3989 3991 3996 4009 4020] 0.6578947368421053

# %%
print(len(best_subset))
#Predict and evaluate
model = FamiliesClusters(np.unique(y),compute_precision,True)
pred = model.fit_predict(DO[:, best_subset],y)

print("sensitivity, specificity, precision, NPV, FDR, FNR = ", compute_statTP(y,pred))
# Out:
# 400
# sensitivity, specificity, precision, NPV, FDR, FNR =  (0.45454545454545453, 0.9972660357518401, 0.6578947368421053, 0.9937133277451802, 0.34210526315789475, 0.5454545454545454)

# %% [markdown]
# # Fisher's score

# %%
N = np.arange(1000,1101,1)
print(N)
# Out:
# [1000 1001 1002 1003 1004 1005 1006 1007 1008 1009 1010 1011 1012 1013
#  1014 1015 1016 1017 1018 1019 1020 1021 1022 1023 1024 1025 1026 1027
#  1028 1029 1030 1031 1032 1033 1034 1035 1036 1037 1038 1039 1040 1041
#  1042 1043 1044 1045 1046 1047 1048 1049 1050 1051 1052 1053 1054 1055
#  1056 1057 1058 1059 1060 1061 1062 1063 1064 1065 1066 1067 1068 1069
#  1070 1071 1072 1073 1074 1075 1076 1077 1078 1079 1080 1081 1082 1083
#  1084 1085 1086 1087 1088 1089 1090 1091 1092 1093 1094 1095 1096 1097
#  1098 1099 1100]

# %%
#N = np.array([800,900,950,1000,1025,1050,1075,1100,])
N = np.arange(500,1101,1)
best_subset, best_score = fishers_score(y, DO, FamiliesClusters,compute_precision,True,N, plot=True)

print(best_subset, best_score)
# Out:
# [   4    5    6 ... 4003 4015 4016] 0.92

# %%
print(len(best_subset))
#Predict and evaluate
model = FamiliesClusters(np.unique(y),compute_precision,True)

pred = model.fit_predict(DO[:, best_subset],y)

print("sensitivity, specificity, precision, NPV, FDR, FNR = ", compute_statTP(y,pred))
# Out:
# 1076
# sensitivity, specificity, precision, NPV, FDR, FNR =  (0.8214285714285714, 0.9989218328840971, 0.92, 0.9973089343379978, 0.08, 0.17857142857142858)

# %% [markdown]
# # Laplacian score

# %%
N = np.arange(900,1501,1)
best_subset, best_score = laplacian_score(y, DO, FamiliesClusters,compute_precision,True, N, plot=True)
print(best_subset, best_score)
# Out:
# [   0    2    6 ... 4017 4019 4020] 1.0

# %%
print(len(best_subset))
#Predict and evaluate
model = FamiliesClusters(np.unique(y),compute_precision,True)
pred = model.fit_predict(DO[:, best_subset],y)

print("sensitivity, specificity, precision, NPV, FDR, FNR = ", compute_statTP(y,pred))
# Out:
# 1151
# sensitivity, specificity, precision, NPV, FDR, FNR =  (0.8571428571428571, 1.0, 1.0, 0.9979550102249489, 0.0, 0.14285714285714285)

# %% [markdown]
# # ReliefF algorithm

# %%
#N = np.array([550,600,650,700,750,800])
N = np.arange(500,531,2)

best_subset, best_score = reliefF(y, DO, FamiliesClusters,compute_precision,True, N, 5, plot=True)
print(best_subset, best_score)
# Out:
# [   0    4    5    7   19   22   28   32   34   72   78   79   80   91
#    96   99  126  128  135  138  139  145  152  160  164  165  167  181
#   184  190  244  266  268  275  286  291  294  295  304  308  313  316
#   353  359  365  384  388  390  394  405  408  409  411  420  422  429
#   445  463  465  469  485  490  494  497  513  518  523  527  536  537
#   563  564  573  583  587  593  601  602  612  632  641  653  655  668
#   679  686  689  690  701  704  719  725  731  733  747  758  771  780
#   786  792  804  808  821  824  831  840  848  849  853  861  863  878
#   886  889  898  918  923  933  953  968  975  990 1000 1005 1009 1014
#  1016 1028 1045 1073 1075 1076 1082 1090 1100 1103 1104 1108 1122 1127
#  1140 1158 1166 1172 1182 1207 1228 1247 1262 1264 1270 1296 1301 1302
#  1329 1337 1339 1341 1342 1353 1370 1372 1376 1379 1441 1449 1460 1473
#  1496 1499 1504 1511 1516 1522 1525 1535 1539 1544 1556 1576 1582 1596
#  1598 1600 1603 1611 1616 1617 1625 1639 1668 1670 1677 1685 1689 1690
#  1692 1694 1716 1721 1723 1729 1738 1739 1748 1750 1753 1764 1775 1785
#  1803 1808 1812 1814 1815 1823 1824 1829 1831 1838 1840 1856 1857 1859
#  1865 1872 1888 1891 1892 1901 1902 1906 1909 1911 1913 1924 1932 1933
#  1942 1949 1962 1963 1968 1970 1981 1983 1992 1994 2014 2015 2016 2027
#  2032 2036 2043 2054 2059 2061 2080 2082 2088 2094 2095 2096 2099 2126
#  2129 2133 2135 2137 2141 2149 2175 2179 2199 2205 2216 2232 2233 2238
#  2242 2266 2282 2288 2294 2297 2309 2320 2321 2325 2332 2346 2347 2351
#  2370 2375 2402 2437 2442 2445 2447 2453 2462 2463 2464 2465 2489 2495
#  2499 2506 2514 2544 2558 2578 2579 2581 2587 2590 2596 2603 2608 2621
#  2627 2632 2633 2635 2646 2678 2679 2682 2686 2687 2691 2696 2700 2704
#  2707 2712 2713 2731 2738 2739 2754 2758 2768 2774 2779 2783 2794 2801
#  2809 2821 2846 2850 2851 2862 2871 2888 2900 2920 2922 2930 2945 2947
#  2948 2950 2951 2957 2961 2992 2993 2994 2999 3001 3003 3004 3008 3009
#  3017 3027 3028 3031 3036 3061 3062 3064 3068 3072 3073 3075 3083 3087
#  3099 3101 3110 3136 3144 3145 3152 3153 3162 3173 3189 3228 3229 3230
#  3260 3262 3270 3274 3276 3288 3302 3307 3334 3335 3339 3348 3354 3373
#  3380 3391 3394 3400 3442 3447 3450 3452 3453 3458 3478 3488 3491 3499
#  3513 3523 3527 3543 3559 3583 3591 3594 3595 3600 3605 3613 3614 3615
#  3616 3625 3629 3633 3634 3658 3660 3669 3674 3684 3688 3699 3708 3716
#  3719 3747 3765 3783 3790 3792 3808 3813 3828 3829 3837 3840 3841 3846
#  3847 3858 3869 3870 3872 3884 3887 3890 3898 3903 3909 3917 3926 3950
#  3957 3958 3972 3973 3979 3982 3998 4007 4008 4009] 0.94

# %%
print(len(best_subset))
#Predict and evaluate
model = FamiliesClusters(np.unique(y),compute_precision,True)
pred = model.fit_predict(DO[:, best_subset],y)

print("sensitivity, specificity, precision, NPV, FDR, FNR = ", compute_statTP(y,pred))
# Out:
# 500
# sensitivity, specificity, precision, NPV, FDR, FNR =  (0.8392857142857143, 0.9991913746630727, 0.94, 0.9975780409041981, 0.06, 0.16071428571428573)

# %% [markdown]
# # Fast Correlation Based Filter algorithm (FCBF)

# %%
N = np.arange(750,851,1)
best_subset, best_score = FCBF(y, DO, FamiliesClusters,compute_precision,True, N, plot=True)
print(best_subset, best_score)
# Out:
# [   4    8    9   20   23   39   42   59   64   65   66  108  115  118
#   129  134  142  145  146  150  156  162  164  165  173  174  179  180
#   185  186  187  191  196  201  212  217  218  223  227  230  233  242
#   245  248  250  253  257  259  268  271  272  287  295  297  306  311
#   313  314  321  323  326  341  349  353  355  356  357  362  363  370
#   378  385  392  404  405  409  418  426  427  432  433  437  440  441
#   448  461  471  472  473  483  498  501  504  507  509  510  515  517
#   526  527  530  534  537  539  541  543  546  548  549  555  561  565
#   578  583  591  608  609  611  627  634  647  653  658  662  664  666
#   673  674  678  679  682  683  684  697  698  701  706  708  710  718
#   726  731  739  755  758  761  769  771  772  776  785  787  788  798
#   800  805  816  817  826  839  841  859  867  873  879  889  895  898
#   910  924  929  937  942  950  955  968  971  972  973  981  983  987
#   988  989  997 1006 1007 1012 1015 1023 1025 1026 1035 1037 1039 1043
#  1051 1055 1058 1065 1067 1077 1084 1086 1088 1089 1095 1096 1097 1102
#  1107 1111 1113 1115 1118 1123 1127 1132 1133 1147 1149 1154 1169 1173
#  1174 1175 1180 1188 1191 1195 1197 1199 1200 1212 1216 1221 1222 1225
#  1239 1241 1243 1252 1267 1295 1306 1310 1313 1316 1318 1323 1335 1349
#  1362 1363 1373 1374 1375 1381 1387 1404 1405 1409 1415 1425 1427 1433
#  1434 1436 1440 1441 1447 1450 1452 1454 1456 1462 1465 1467 1470 1472
#  1487 1492 1493 1498 1499 1502 1518 1519 1523 1529 1537 1539 1541 1543
#  1546 1547 1549 1550 1554 1558 1562 1571 1574 1579 1581 1582 1583 1584
#  1588 1595 1599 1600 1610 1616 1618 1626 1630 1632 1643 1644 1652 1656
#  1660 1665 1668 1681 1685 1690 1695 1701 1702 1708 1711 1713 1716 1728
#  1734 1736 1741 1746 1749 1750 1755 1758 1769 1770 1773 1777 1778 1791
#  1795 1806 1808 1809 1813 1822 1827 1842 1844 1853 1854 1867 1868 1879
#  1881 1885 1886 1887 1901 1904 1909 1912 1913 1918 1924 1925 1929 1930
#  1933 1940 1942 1944 1953 1970 1972 1977 1979 1980 1985 1988 1992 1998
#  2001 2002 2009 2014 2022 2025 2026 2027 2028 2037 2043 2044 2051 2054
#  2065 2068 2070 2083 2097 2109 2123 2135 2140 2144 2161 2167 2169 2170
#  2172 2174 2176 2180 2191 2192 2196 2206 2221 2228 2242 2246 2251 2253
#  2255 2259 2265 2266 2269 2272 2275 2284 2288 2290 2294 2300 2301 2305
#  2312 2314 2325 2328 2330 2332 2338 2340 2350 2351 2354 2362 2366 2367
#  2370 2377 2380 2392 2398 2403 2409 2410 2413 2414 2421 2427 2431 2435
#  2436 2438 2440 2442 2447 2455 2463 2465 2467 2473 2481 2485 2487 2493
#  2495 2502 2505 2507 2512 2520 2521 2530 2531 2533 2534 2536 2538 2549
#  2553 2556 2559 2561 2562 2569 2571 2573 2576 2581 2587 2591 2593 2596
#  2597 2598 2600 2611 2613 2624 2625 2635 2641 2658 2661 2663 2670 2680
#  2682 2686 2693 2694 2696 2701 2702 2706 2708 2709 2711 2720 2721 2731
#  2739 2742 2749 2762 2763 2781 2802 2808 2812 2815 2818 2820 2829 2851
#  2857 2890 2896 2897 2904 2907 2914 2940 2948 2953 2954 2956 2961 2966
#  2968 2978 2982 3004 3008 3025 3029 3044 3046 3052 3056 3060 3061 3064
#  3068 3070 3076 3077 3083 3094 3099 3108 3109 3111 3113 3118 3120 3124
#  3142 3145 3147 3150 3151 3167 3168 3170 3171 3175 3176 3180 3185 3188
#  3201 3206 3208 3209 3218 3221 3223 3224 3229 3240 3244 3245 3248 3249
#  3260 3267 3271 3284 3297 3304 3312 3315 3318 3336 3337 3343 3348 3350
#  3351 3365 3368 3369 3372 3373 3379 3386 3387 3390 3396 3400 3403 3416
#  3420 3430 3433 3442 3443 3446 3450 3457 3459 3463 3474 3487 3490 3493
#  3496 3500 3502 3503 3504 3509 3512 3514 3519 3523 3525 3528 3530 3543
#  3578 3579 3585 3587 3592 3600 3601 3602 3617 3621 3627 3633 3635 3638
#  3642 3646 3647 3648 3649 3650 3655 3658 3659 3669 3673 3679 3686 3692
#  3693 3696 3697 3700 3702 3705 3710 3714 3720 3722 3727 3735 3750 3753
#  3754 3769 3771 3773 3775 3778 3784 3785 3788 3790 3795 3799 3802 3811
#  3816 3817 3819 3824 3828 3833 3834 3836 3838 3839 3854 3856 3861 3874
#  3875 3876 3882 3890 3892 3893 3897 3906 3910 3932 3943 3944 3953 3959
#  3966 3974 3975 3978 3980 3981 3983 3984 3986 3989 3990 3993 3999 4001
#  4011 4016 4018 4019 4020] 0.926829268292683

# %%
print(len(best_subset))
#Predict and evaluate
model = FamiliesClusters(np.unique(y),compute_precision,True)
pred = model.fit_predict(DO[:, best_subset],y)

print("sensitivity, specificity, precision, NPV, FDR, FNR = ", compute_statTP(y,pred))
# Out:
# 789
# sensitivity, specificity, precision, NPV, FDR, FNR =  (0.6785714285714286, 0.9993362831858407, 0.926829268292683, 0.9960308710033076, 0.07317073170731707, 0.32142857142857145)

# %% [markdown]
# # Hilbert Schmidt Independence Criterion Lasso (HSIC Lasso)

# %%
N = np.arange(70,90,1)
best_subset, best_score = HsicLasso(y, DO, FamiliesClusters,compute_precision,True, N, plot=True)
print(best_subset, best_score)
# Out:
# Block HSIC Lasso B = 20.
# M set to 3.
# Using Gaussian kernel for the features, Delta kernel for the outcomes.
# C:\Users\Imane\anaconda3\lib\site-packages\pyHSICLasso\api.py:107: RuntimeWarning: B 20 must be an exact divisor of the number of samples 112. Number of blocks 5.6 will be approximated to 5.
#   warnings.warn(msg, RuntimeWarning)
# Block HSIC Lasso B = 20.
# M set to 3.
# Using Gaussian kernel for the features, Delta kernel for the outcomes.
# Block HSIC Lasso B = 20.
# M set to 3.
# Using Gaussian kernel for the features, Delta kernel for the outcomes.
# Block HSIC Lasso B = 20.
# M set to 3.
# Using Gaussian kernel for the features, Delta kernel for the outcomes.
# Block HSIC Lasso B = 20.
# M set to 3.
# Using Gaussian kernel for the features, Delta kernel for the outcomes.
# Block HSIC Lasso B = 20.
# M set to 3.
# Using Gaussian kernel for the features, Delta kernel for the outcomes.
# Block HSIC Lasso B = 20.
# M set to 3.
# Using Gaussian kernel for the features, Delta kernel for the outcomes.
# Block HSIC Lasso B = 20.
# M set to 3.
# Using Gaussian kernel for the features, Delta kernel for the outcomes.
# Block HSIC Lasso B = 20.
# M set to 3.
# Using Gaussian kernel for the features, Delta kernel for the outcomes.
# Block HSIC Lasso B = 20.
# M set to 3.
# Using Gaussian kernel for the features, Delta kernel for the outcomes.
# Block HSIC Lasso B = 20.
# M set to 3.
# Using Gaussian kernel for the features, Delta kernel for the outcomes.
# Block HSIC Lasso B = 20.
# M set to 3.
# Using Gaussian kernel for the features, Delta kernel for the outcomes.
# Block HSIC Lasso B = 20.
# M set to 3.
# Using Gaussian kernel for the features, Delta kernel for the outcomes.
# Block HSIC Lasso B = 20.
# M set to 3.
# Using Gaussian kernel for the features, Delta kernel for the outcomes.
# Block HSIC Lasso B = 20.
# M set to 3.
# Using Gaussian kernel for the features, Delta kernel for the outcomes.
# Block HSIC Lasso B = 20.
# M set to 3.
# Using Gaussian kernel for the features, Delta kernel for the outcomes.
# Block HSIC Lasso B = 20.
# M set to 3.
# Using Gaussian kernel for the features, Delta kernel for the outcomes.
# Block HSIC Lasso B = 20.
# M set to 3.
# Using Gaussian kernel for the features, Delta kernel for the outcomes.
# Block HSIC Lasso B = 20.
# M set to 3.
# Using Gaussian kernel for the features, Delta kernel for the outcomes.
# Block HSIC Lasso B = 20.
# M set to 3.
# Using Gaussian kernel for the features, Delta kernel for the outcomes.
# [  24   73  103  149  203  230  269  364  486  599  637  638  639  640
#   659  788  921  937  957 1018 1042 1057 1195 1272 1282 1302 1310 1344
#  1376 1380 1395 1429 1443 1446 1532 1535 1586 1737 1784 1811 1849 1892
#  1935 1969 2012 2019 2036 2088 2110 2220 2229 2243 2251 2306 2342 2394
#  2402 2432 2447 2490 2491 2586 2593 2600 2607 2712 2744 2801 2898 2974
#  3004 3012 3041 3214 3300 3447 3468 3476 3560 3595 3616 3810 3901 3961
#  4004] 1.0

# %%
print(len(best_subset))
#Predict and evaluate
model = FamiliesClusters(np.unique(y),compute_precision,True)
pred = model.fit_predict(DO[:, best_subset],y)

print("sensitivity, specificity, precision, NPV, FDR, FNR = ", compute_statTP(y,pred))
# Out:
# 85
# sensitivity, specificity, precision, NPV, FDR, FNR =  (0.9285714285714286, 1.0, 1.0, 0.9988610478359908, 0.0, 0.07142857142857142)

# %% [markdown]
# # Wrapper methods

# %% [markdown]
# # Stochastic optimization of features selection

# %%
best_subset, best_score  = hillclimbing(y, DO, FamiliesClusters, compute_sensitivity,True, 1000, 0.1, True)
print(best_score)
# Out:
# 0.9642857142857143

# %%
print(len(best_subset))
#Predict and evaluate
model = FamiliesClusters(np.unique(y),compute_sensitivity,True)
pred = model.fit_predict(DO[:, best_subset],y)

print("sensitivity, specificity, precision, NPV, FDR, FNR = ", compute_statTP(y,pred))
# Out:
# 1993
# sensitivity, specificity, precision, NPV, FDR, FNR =  (0.9642857142857143, 1.0, 1.0, 0.9993939393939394, 0.0, 0.03571428571428571)

# %% [markdown]
# # Stimulated annealing

# %%
best_subset, best_score  = stimulated_annealing(y, DO, FamiliesClusters, compute_sensitivity,True, 1500, 0.1, 1, True)
print(best_score)
# Out:
# 0.9642857142857143

# %%
print(len(best_subset))
#Predict and evaluate
model = FamiliesClusters(np.unique(y),compute_sensitivity,True)
pred = model.fit_predict(DO[:, best_subset],y)

print("sensitivity, specificity, precision, NPV, FDR, FNR = ", compute_statTP(y,pred))
# Out:
# 1995
# sensitivity, specificity, precision, NPV, FDR, FNR =  (0.9642857142857143, 1.0, 1.0, 0.9993939393939394, 0.0, 0.03571428571428571)

# %% [markdown]
# # Genetic feature selection algorithm

# %%
best_subset, best_score  = genetic_fs(y,DO,FamiliesClusters,compute_sensitivity,True, 500, 0.5, 0.2, 50, 3, True)
print(best_score)
# Out:
# 0.9775757575757578

# %%
print(len(best_subset))
#Predict and evaluate
model = FamiliesClusters(np.unique(y),compute_sensitivity,True)
pred = model.fit_predict(DO[:, best_subset],y)

print("sensitivity, specificity, precision, NPV, FDR, FNR = ", compute_statTP(y,pred))
# Out:
# 1719
# sensitivity, specificity, precision, NPV, FDR, FNR =  (0.9821428571428571, 1.0, 1.0, 0.9996866186148543, 0.0, 0.017857142857142856)

# %% [markdown]
# # Hybrid methods

# %% [markdown]
# # Mutual information and stimulated annealing

# %%
DO_best_subset, best_score = MI_stimulated_annealing(y,DO, FamiliesClusters, compute_sensitivity,True, np.array([100]), 3, 5000, 0.05, 1, True)
print(DO_best_subset, best_score)
# Out:
# [   9   93  145  230  347  381  401  436  638  639  640  685  717  733
#   872  953 1108 1198 1247 1302 1431 1443 1648 1749 1812 1891 2011 2042
#  2088 2229 2277 2412 2457 2488 2633 2712 2750 2842 2843 2986 3007 3012
#  3214 3633 3840 3874 3901 3922] 1.0

# %%
print(len(DO_best_subset))
#Predict and evaluate
model = FamiliesClusters(np.unique(y),compute_sensitivity,True)
pred = model.fit_predict(DO[:, DO_best_subset],y)

print("sensitivity, specificity, precision, NPV, FDR, FNR = ", compute_statTP(y,pred))
# Out:
# 48
# sensitivity, specificity, precision, NPV, FDR, FNR =  (1.0, 1.0, 1.0, 1.0, 0.0, 0.0)

# %% [markdown]
# # Mutual information and genetic feature selection

# %%
best_subset, best_score = MI_genetic_fs(y,DO, FamiliesClusters, compute_sensitivity,True, np.array([300]), 3,  300, 0.5, 0.2, 200, 3, True)
print(best_subset, best_score)
# Out:
# [  34   49   62   93  109  169  301  347  430  497  528  550  582  639
#   759  936  937 1226 1231 1249 1329 1380 1419 1698 1741 1864 2219 2243
#  2274 2412 2749 2842 2871 3007 3070 3143 3214 3226 3370 3469 3508 3705
#  3840 3955] 1.0

# %%
print(len(best_subset))
#Predict and evaluate
model = FamiliesClusters(np.unique(y),compute_precision,True)
pred = model.fit_predict(DO[:, best_subset],y)

print("sensitivity, specificity, precision, NPV, FDR, FNR = ", compute_statTP(y,pred))
# Out:
# 44
# sensitivity, specificity, precision, NPV, FDR, FNR =  (1.0, 1.0, 1.0, 1.0, 0.0, 0.0)

# %%
DO_best = get_best_genes_names(DO_best_subset, '../data/processed_data/DOgenes_interest.csv' ,'../data/optimized_subsets/DOgenes_best.csv')
