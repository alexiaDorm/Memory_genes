# %%
import numpy as np
import matplotlib.pyplot as plt

import io 
import pandas as pd  
import pyreadr

from load_data import *
from pred_score import *
from Filter_FS import *
from hybrid_FS import *
from overlap_genes import *
from crossValidation import *

# %%
#Fixing seed to get reproducible results
random.seed(3)
np.random.seed(3)

# %% [markdown]
# # Baseline with preselected genes

# %%
#Load preprocess data
AE3= np.array(pd.read_csv ('../data/processed_data/AE3.csv'))
y = np.array(AE3[:,-1],dtype=int)
AE3 = AE3[:,0:-1]

# %%
#Predict and evaluate
model = FamiliesClusters(np.unique(y),compute_precision,True)
pred = model.fit_predict(AE3,y)

# %%
print(AE3.shape, len(pred))
acc = model.score_
print(acc)
# Out:
# (333, 5778) 333
# 0.3159509202453988

# %%
print("TP, FP, ratio, sensitivity, specificity, precision, NPV, FDR, FNR = ", compute_statTP(y,pred))
# Out:
# TP, FP, ratio, sensitivity, specificity, precision, NPV, FDR, FNR =  (103.0, 223.0, 0.4618834080717489, 0.37050359712230213, 0.9921779087305763, 0.3159509202453988, 0.9938512350233653, 0.6840490797546013, 0.6294964028776978)

# %% [markdown]
# # Mutual information maximizer (MIM)

# %%
#Define parameters for MIM method
N = np.arange(80,1500,30)
kwargs = {'Model': FamiliesClusters, 'Scoring': compute_precision,'maximize': True,'N': N, 'n_neighbors': 3, 'plot': True} 

subset, score_training, score_testing = cross_validation(y,AE3, FamiliesClusters, compute_precision,True, 5,  MIM, **kwargs)

mean_score_test, std_score_test = np.mean(score_testing), np.std(score_testing)    
print('test', mean_score_test, std_score_test)

#Predict and evaluate on whole data  set
model = FamiliesClusters(np.unique(y),compute_precision,True)
x_subset = AE3[:, subset]
pred = model.fit_predict(x_subset,y)

print("TP, FP, ratio, sensitivity, specificity, precision, NPV, FDR, FNR = ", compute_statTP(y,pred))
# Out:
# test 0.500318312005778 0.12440248004497897
# TP, FP, ratio, sensitivity, specificity, precision, NPV, FDR, FNR =  (183.0, 218.0, 0.8394495412844036, 0.7204724409448819, 0.9846142988213706, 0.456359102244389, 0.9949365283126516, 0.543640897755611, 0.2795275590551181)

# %% [markdown]
# # Anova F test

# %%
#Define parameters for ANOVA method
N = np.arange(80,3000,30)
kwargs = {'Model': FamiliesClusters, 'Scoring': compute_precision,'maximize': True,'N': N, 'plot': True} 

subset, score_training, score_testing = cross_validation(y,AE3, FamiliesClusters, compute_precision,True, 5,  ANOVA, **kwargs)

mean_score_test, std_score_test = np.mean(score_testing), np.std(score_testing)    
print('test', mean_score_test, std_score_test)

#Predict and evaluate on whole data  set
model = FamiliesClusters(np.unique(y),compute_precision,True)
x_subset = AE3[:, subset]
pred = model.fit_predict(x_subset,y)

print("TP, FP, ratio, sensitivity, specificity, precision, NPV, FDR, FNR = ", compute_statTP(y,pred))
# Out:
# test 0.5050293179518975 0.06309170706122079
# TP, FP, ratio, sensitivity, specificity, precision, NPV, FDR, FNR =  (177.0, 207.0, 0.855072463768116, 0.6321428571428571, 0.988571113074205, 0.4609375, 0.9942803198578409, 0.5390625, 0.3678571428571429)

# %% [markdown]
# # Hybrid methods

# %% [markdown]
# # Mutual information and stimulated annealing

# %%
#Define parameters for MI + stimulated annealing method
N = np.array([700])
kwargs = {'Model': FamiliesClusters, 'Scoring': compute_precision,'maximize': True,'N': N, 'n_iter': 1400, 'n_neighbors': 3, 'p_mutate': 0.1, 'c': 1, 'plot': True} 

subset, score_training, score_testing = cross_validation(y,AE3, FamiliesClusters, compute_precision,True, 5,  MI_stimulated_annealing, **kwargs)

mean_score_test, std_score_test = np.mean(score_testing), np.std(score_testing)    
print('test', mean_score_test, std_score_test)

#Predict and evaluate on whole data  set
model = FamiliesClusters(np.unique(y),compute_precision,True)
x_subset = AE3[:, subset]
pred = model.fit_predict(x_subset,y)

print("TP, FP, ratio, sensitivity, specificity, precision, NPV, FDR, FNR = ", compute_statTP(y,pred))
# Out:
# test 0.5302438506311775 0.10916047811596566
# TP, FP, ratio, sensitivity, specificity, precision, NPV, FDR, FNR =  (194.0, 236.0, 0.8220338983050848, 0.7637795275590551, 0.981042654028436, 0.4511627906976744, 0.9951112197506722, 0.5488372093023256, 0.23622047244094488)

# %% [markdown]
# # Mutual information and genetic feature selection

# %%
#Define parameters for MI + genetic algorithm method
N = np.array([700])                            
kwargs = {'Model': FamiliesClusters, 'Scoring': compute_precision,'maximize': True,'N': N, 'n_neighbors': 3, 'n_population': 300, 'crossover_proba': 0.5, 'mutation_proba': 0.2, 'n_generations': 120, 'tournament_size': 3, 'plot': True} 

subset, score_training, score_testing = cross_validation(y,AE3, FamiliesClusters, compute_precision,True, 5,  MI_genetic_fs, **kwargs)

mean_score_test, std_score_test = np.mean(score_testing), np.std(score_testing)    
print('test', mean_score_test, std_score_test)

#Predict and evaluate on whole data  set
model = FamiliesClusters(np.unique(y),compute_precision,True)
x_subset = AE3[:, subset]
pred = model.fit_predict(x_subset,y)

print("TP, FP, ratio, sensitivity, specificity, precision, NPV, FDR, FNR = ", compute_statTP(y,pred))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-9b117aaca131> in <module>
#       3 kwargs = {'Model': FamiliesClusters, 'Scoring': compute_precision,'maximize': True,'N': N, 'n_neighbors': 3, 'n_population': 300, 'crossover_proba': 0.5, 'mutation_proba': 0.2, 'n_generations': 120, 'tournament_size': 3, 'plot': True}
#       4
# ----> 5 subset, score_training, score_testing = cross_validation(y,AE3, FamiliesClusters, compute_precision,True, 5,  MI_genetic_fs, **kwargs)
#       6
#       7 mean_score_test, std_score_test = np.mean(score_testing), np.std(score_testing)
#
# ~\Desktop\Memory_genes\src\crossValidation.py in cross_validation(y, x, Model_test, Scoring_test, maximize_test, kfold, func, **kwargs)
#     129
#     130         #Run feature selection on training set
# --> 131         subset, score = func(y_train, x_train, **kwargs)
#     132
#     133         #Evaluate subset on test set
#
# ~\Desktop\Memory_genes\src\hybrid_FS.py in MI_genetic_fs(y, x, Model, Scoring, maximize, N, n_neighbors, n_population, crossover_proba, mutation_proba, n_generations, tournament_size, plot)
#      94
#      95     #Run gentic algorithm on MI subset
# ---> 96     subset, best_score = genetic_fs(y,xMI, Model, Scoring, maximize, n_population, crossover_proba, mutation_proba, n_generations, tournament_size, plot)
#      97
#      98     best_subset = subsetMI[subset]
#
# ~\Desktop\Memory_genes\src\Wrapper_FS.py in genetic_fs(y, x, Model, Scoring, maximize, n_population, crossover_proba, mutation_proba, n_generations, tournament_size, plot)
#     275     fs = GeneticSelectionCV(estimator = model, n_jobs=-1, n_population=n_population, crossover_proba=crossover_proba, mutation_proba=mutation_proba, n_generations=n_generations, crossover_independent_proba=0.1,mutation_independent_proba=0.05, tournament_size=tournament_size, caching=True)
#     276
# --> 277     fs.fit(x, y)
#     278
#     279     #Get the selected features and final score
#
# ~\anaconda3\lib\site-packages\genetic_selection\gscv.py in fit(self, X, y)
#     280             The target values.
#     281         """
# --> 282         return self._fit(X, y)
#     283
#     284     def _fit(self, X, y):
#
# ~\anaconda3\lib\site-packages\genetic_selection\gscv.py in _fit(self, X, y)
#     342             print("Selecting features with genetic algorithm.")
#     343
# --> 344         _, log = _eaFunction(pop, toolbox, cxpb=self.crossover_proba, mutpb=self.mutation_proba,
#     345                              ngen=self.n_generations, ngen_no_change=self.n_gen_no_change,
#     346                              stats=stats, halloffame=hof, verbose=self.verbose)
#
# ~\anaconda3\lib\site-packages\genetic_selection\gscv.py in _eaFunction(population, toolbox, cxpb, mutpb, ngen, ngen_no_change, stats, halloffame, verbose)
#      78         # Evaluate the individuals with an invalid fitness
#      79         invalid_ind = [ind for ind in offspring if not ind.fitness.valid]
# ---> 80         fitnesses = toolbox.map(toolbox.evaluate, invalid_ind)
#      81         for ind, fit in zip(invalid_ind, fitnesses):
#      82             ind.fitness.values = fit
#
# ~\anaconda3\lib\multiprocessing\pool.py in map(self, func, iterable, chunksize)
#     362         in a list that is returned.
#     363         '''
# --> 364         return self._map_async(func, iterable, mapstar, chunksize).get()
#     365
#     366     def starmap(self, func, iterable, chunksize=None):
#
# ~\anaconda3\lib\multiprocessing\pool.py in get(self, timeout)
#     763
#     764     def get(self, timeout=None):
# --> 765         self.wait(timeout)
#     766         if not self.ready():
#     767             raise TimeoutError
#
# ~\anaconda3\lib\multiprocessing\pool.py in wait(self, timeout)
#     760
#     761     def wait(self, timeout=None):
# --> 762         self._event.wait(timeout)
#     763
#     764     def get(self, timeout=None):
#
# ~\anaconda3\lib\threading.py in wait(self, timeout)
#     556             signaled = self._flag
#     557             if not signaled:
# --> 558                 signaled = self._cond.wait(timeout)
#     559             return signaled
#     560
#
# ~\anaconda3\lib\threading.py in wait(self, timeout)
#     300         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     301             if timeout is None:
# --> 302                 waiter.acquire()
#     303                 gotit = True
#     304             else:
#
# KeyboardInterrupt:
